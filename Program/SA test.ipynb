# %%
def domneva(G):
    if G.is_connected() == False:
        return None
    B = set(G.periphery())
    d = G.distance_all_pairs()
    razdalja = []
    for v in G:
        if v not in B:
            sezv = []
            for u in B:
                sezv.append(d[v][u])
            razdalja.append(min(sezv))
    razlika = 2 * G.dominating_set(total=True, value_only=True) - G.radius() - (max(razdalja) if razdalja else 0)
    if razlika < 0:
        return False
    else: return razlika

# %%
import datetime
print(datetime.datetime.now())


def simulacija():
    rez = 100
    n = 15
    G = graphs.RandomGNP(n,0.4)
    k = 0
    p = 0.91
    
    while k < 1000000: #število korakov od k=0 do k=499
        if G.is_connected()== False:
            G = graphs.RandomGNP(n,0.4)
            k +=1
            
        v1 = choice(list(range(n))) #naključni vozlišči v1, v2
        v2 = choice(list(range(n)))
        
        if v1 != v2:
            verj = random() #verjetnost s katero določim ali nadaljujem po 'boljšem' grafu
                            #s tem se izognem, da bi zašel v lokalni ekstrem
            if v2 not in G.edges()[v1]:
                G.add_edge(v1,v2)
                razlika = domneva(G)
                if razlika == False:
                    return [G,razlika]
                elif razlika < rez:#nadaljevanje poteka vedno le za enake ali boljše vrednosti
                    rez = razlika  #sicer nikakor ne konvergiramo k globalnemu ekstremu
                    k+=1
                elif razlika == rez:
                    if verj > p: #1-p da ostanem v tem grafu
                        G.delete_edge(v1,v2)
                    k+=1
                else: #razlika > rez
                    if verj < p:
                        G.delete_edge(v1,v2)
                    else: #korak v 'slabše'
                        rez = razlika
                    k+=1 
                    
            else:
                G.delete_edge(v1,v2)
                razlika = domneva(G)
                if razlika == None:
                    G.add_edge(v1,v2)
                    k+=1
                elif razlika == False:
                    return [G,razlika]
                elif razlika < rez:
                    rez = razlika
                    k+=1
                elif razlika == rez:
                    if verj > p:
                        G.add_edge(v1,v2)
                    k+=1
                else:
                    if verj < p:
                        G.add_edge(v1,v2)
                    else:
                        rez = razlika
                    k+=1
                
        else:
            k+=1
            
    return [G,rez]


G,rez = simulacija()   
print(datetime.datetime.now())
